# %%
#Store the name of your favourite hobby and how many hours a week you spend on it, then print both together in one sentence.
favourite_hobby={"name":"Singing" , "hours": 4 }
print("my favourite hobby is ",favourite_hobby["name"], "i spend",favourite_hobby ["hours"], "hours")
# Out:
# my favourite hobby is  Singing i spend 4 hours

# %%
#Ask the user to enter their favourite season and print a short reaction message that includes it.
season=input("Enter your favourite season:")
print("O my god! i love this ", season,"Season")
# Out:
# O my god! i love this  Rainy Season

# %%
#A queue token number is received as text at a service counter, for example "128".Confirm what type this value is when it's received, then convert it to a number and print the next token number to be called.
token="128"
print(type(token))
token_1=int(token)
next_token=token_1+1
print("next token number is:", next_token)
# Out:
# <class 'str'>
# next token number is: 129

# %%
#A car service bill lists these charges: 850, 320, 175, 60.Store them together and print the total service cost.
bill=[850, 320, 175, 60]
total_cost=sum(bill)
print("total service cost is:" , total_cost)
# Out:
# total service cost is: 1405

# %%
#A weekly timetable has periods listed in a fixed order: ("Math", "Science", "Art").Print the middle period.
periods=("Math", "Science", "Art")
print("the middle period is: ",periods[1])
# Out:
# the middle period is:  Science

# %%
#A college name is stored as " st. joseph college ".Print it properly formatted —without the extra spaces, and with each word capitalized.
name="st. joseph college"
name=name.strip()
name=name.title()
print(name)
# Out:
# St. Joseph College

# %%
#A parking lot tracks its occupied slots as {"P1", "P4", "P7"}.Check whether slot "P4" is already occupied.
occupied_slots={"P1", "P4", "P7"}
print("is P4 occupied: ","P4" in occupied_slots)
# Out:
# is P4 occupied:  True

# %%
# A pet listed for adoption has its details stored as{"name": "Bruno", "breed":"Labrador", "age": 2}.Print the pet's breed.
pet_list={"name": "Bruno", "breed":"Labrador", "age": 2}
print("Pet's breed is ",pet_list["breed"])
# Out:
# Pet's breed is  Labrador

# %%
#Two photographers tag their portfolio images separately:tags1 = ["sunset","portrait"] and tags2 = ["portrait", "wildlife"].Combine both lists into one, then print only the distinct tags from it.
tags1 = ["sunset","portrait"]
tags2 = ["portrait", "wildlife"]

tags=tags1+tags2
print(tags)
# Out:
# ['sunset', 'portrait', 'portrait', 'wildlife']

# %%
#A currency counter converts US Dollars to Rupees at a fixed rate of Rs. 83 per dollar. For an exchange of 25 dollars, print the amount in rupees.
indian_rupee_per_dollar=83
dollar=25
print("25 dollars in indian rupees: ",indian_rupee_per_dollar* dollar)
# Out:
# 25 dollars in indian rupees:  2075

# %%
#A café order is being customised: the customer wants oat milk and wants it extra hot.Given both preferences are True, print whether the order counts as a custom brew, which requires both to be True.
oat_milk=True
extra_hot=True
custom_brew= oat_milk and extra_hot
print(custom_brew)
# Out:
# True

# %%
#A courier tracking code is stored as "TRK458821". Print how many characters long it is.
code="TRK458821"
print("no. of characters in it : ",len(code))
# Out:
# no. of characters in it :  9

# %%
#A flight's journey details are stored as ("Kochi", "Dubai", "6 hours"). Print the duration of the flight from it.
details=("Kochi", "Dubai", "6 hours")
print("duration of flight is ",details[2])
# Out:
# duration of flight is  6 hours

# %%
#A fitness app awards 1 point for every 1000 steps walked. A user walked 7300 steps today.Using an f-string, print their points earned in the form "Points earned: 7".

# %%
#A mobile SIM's recharge balance is Rs. 1200. After a pack deduction of Rs. 350,update the balance and print the new amount.
balance=1200
deduction=350
new_balance=balance-deduction
print("the balance amount is :",new_balance)
# Out:
# the balance amount is : 850
