# %%
#Store your date of birth as a tuple in the format (day, month, year) and print it.
DOB=(18,"September",2002)
print(DOB)
print(type(DOB))
# Out:
# (18, 'September', 2002)
# <class 'tuple'>

# %%
#A GPS location is given as (12.9716, 77.5946). Print the latitude and the longitude separately.
location=(12.9716, 77.5946)
print("latitude is give as: " ,location[0])
print("longitude is given as: " ,location[1])
# Out:
# latitude is give as:  12.9716
# longitude is given as:  77.5946

# %%
#A product's details are stored as ("Laptop", 55000, "Electronics"). Print the price alone.
product=("Laptop", 55000, "Electronics")
print("price of the product is given as : ",product[1])
# Out:
# price of the product is given as :  55000

# %%
#Try changing the price in the tuple from the previous question directly to 60000. Run it, see what happens,and write down the result as a comment in your code. 
product=("Laptop", 55000, "Electronics")
product[1]=60000
print(product)#error because tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #Try changing the price in the tuple from the previous question directly to 60000. Run it, see what happens,and write down the result as a comment in your code.
#       2 product=("Laptop", 55000, "Electronics")
# ----> 3 product[1]=60000
#       4 print(product)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#A traffic light shows only three states: ("Red", "Yellow", "Green"). Print how many states it contains.
traffic_light=("Red", "Yellow", "Green")
print("no.of states it contains is: ", len(traffic_light))
# Out:
# no.of states it contains is:  3

# %%
#A movie's rating history is (4, 5, 3, 5, 5, 2). Print how many times it was rated 5.
rating=(4, 5, 3, 5, 5, 2)
print("no.of times 5 was rated: " , rating.count(5))
# Out:
# no.of times 5 was rated:  3

# %%
#Convert the list ["Monday", "Tuesday", "Wednesday"] into a tuple and print it.
list=["Monday", "Tuesday", "Wednesday"]
list1=tuple(list)
print(list1)
# Out:
# ('Monday', 'Tuesday', 'Wednesday')

# %%
#Store your name, age, and city together in a single tuple, then unpack it into three separate variables and print each one individually.
info=("aysha",24,"vadakara")
name=info[0]
age=info[1]
city=info[2]
print("name : " ,name)
print("age: ",age)
print("city: ",city)
# Out:
# name :  aysha
# age:  24
# city:  vadakara

# %%
#A store's opening and closing time are stored together as ("09:00 AM", "09:00 PM").Print the position of "09:00 PM" in the tuple.
time=("09:00 AM", "09:00 PM")
print("position of 09:00 PM: ",time.index("09:00 PM"))
# Out:
# position of 09:00 PM:  1

# %%
#Two friends share their favourite colours as color1 = ("Blue", "Green") and color2 =("Red", "Yellow").Combine both into a single tuple and print it.
color1 = ("Blue", "Green")
color2 =("Red", "Yellow")
colors=color1+color2
print(colors)
# Out:
# ('Blue', 'Green', 'Red', 'Yellow')

# %%
#A recipe needs exactly three ingredients in a fixed order: ("Flour", "Sugar", "Eggs").Print the ingredients in reverse order without changing the original tuple.
recipe=("Flour", "Sugar", "Eggs")
print("this in reverse order is: ",recipe[ : :-1])
# Out:
# this in reverse order is:  ('Eggs', 'Sugar', 'Flour')

# %%
#A student's marks in 3 subjects are given as (78, 85, 92). Print the total and the average.
marks=(78, 85, 92)
print("sum of the marks : " , sum(marks))
print("average of the marks is: ",sum(marks)/len(marks))
# Out:
# sum of the marks :  255
# average of the marks is:  85.0

# %%
#A survey asked 6 people their favourite programming language:["Python", "Java","Python", "C++", "Java", "Python"].Store the responses and print only the distinct languages mentioned.
language=["Python", "Java","Python", "C++", "Java", "Python"]
set(language)
# Out:
# {'C++', 'Java', 'Python'}

# %%
#Two gyms report their members' names: gymA = {"Ravi", "Sneha", "Kiran", "Alok"} and gymB = {"Kiran", "Meera", "Alok", "Priya"}.Print everyone who is a member of atleast one gym.
gymA = {"Ravi", "Sneha", "Kiran", "Alok"}
gymB = {"Kiran", "Meera", "Alok", "Priya"}
gymA|gymB
# Out:
# {'Alok', 'Kiran', 'Meera', 'Priya', 'Ravi', 'Sneha'}

# %%
#Using the same two gyms above, print the names of people who are members of both gyms.
gymA = {"Ravi", "Sneha", "Kiran", "Alok"}
gymB = {"Kiran", "Meera", "Alok", "Priya"}
gymA & gymB
# Out:
# {'Alok', 'Kiran'}

# %%
#Using the same two gyms above, print the names of people who are members of gymA only.
gymA = {"Ravi", "Sneha", "Kiran", "Alok"}
gymB = {"Kiran", "Meera", "Alok", "Priya"}
gymA-gymB
# Out:
# {'Ravi', 'Sneha'}

# %%
#A user's email is stored as "priya.sharma@gmail.com".Store the set of allowed email domains as {"gmail.com", "yahoo.com", "outlook.com"}and check whether "gmail.com" is part of that allowed set.
mail_id="priya.sharma@gmail.com"
allowed_domains={"gmail.com", "yahoo.com", "outlook.com"}
print("gmail.com" in mail_id)
# Out:
# True

# %%
#A trip itinerary visited these cities in order: ("Delhi", "Agra", "Jaipur", "Delhi", "Agra").Print how many distinct cities were actually visited.
cities=("Delhi", "Agra", "Jaipur", "Delhi", "Agra")
print("distinct cities they visisted: ", set(cities))
# Out:
# distinct cities they visisted:  {'Jaipur', 'Delhi', 'Agra'}

# %%
#A teacher wants to combine two attendance sheets recorded separately as lists:morning = ["Ana", "Ben", "Cara", "Ana"] and afternoon = ["Ben", "Dev", "Cara"].Print the names of students who attended only in the morning.
morning_list=set(["Ana", "Ben", "Cara", "Ana"])
afternoon_list=set(["Ben", "Dev", "Cara"])
print(morning_list)
print(afternoon_list)
morning_list-afternoon_list#names of students who attended only in the morning.
# Out:
# {'Cara', 'Ben', 'Ana'}
# {'Cara', 'Ben', 'Dev'}
# {'Ana'}

# %%
#A gaming platform keeps a set of banned usernames: {"troll99", "hacker007","spammer1"}.A new player wants the username "hacker007"— check and printwhether this username is already banned.
usernames={"troll99", "hacker007","spammer1"}
print("is hacker007 there in usernames: ", "hacker007" in usernames)
# Out:
# is hacker007 there in usernames:  True

# %%
#A recipe blog tags two of its posts as post1 = ["vegan", "quick", "dinner"]and post2 =["dinner", "vegan", "healthy"].Print the tags that appear in both posts.
post1 = set(["vegan", "quick", "dinner"])
post2 =set(["dinner", "vegan", "healthy"])
print(post1)
print(post2)
post1 & post2 # tags that appears in both
# Out:
# {'vegan', 'quick', 'dinner'}
# {'healthy', 'vegan', 'dinner'}
# {'dinner', 'vegan'}

# %%
#A company's office branches are stored as a tuple:("Mumbai", "Delhi", "Pune","Mumbai", "Chennai").Print the number of unique branch cities the company operates in.
cities=("Mumbai", "Delhi", "Pune","Mumbai", "Chennai")
print("unique branch cities are: ",set(cities))
# Out:
# unique branch cities are:  {'Chennai', 'Mumbai', 'Delhi', 'Pune'}

# %%
#A library has these book titles currently issued:issued = {"Dune", "1984", "Emma"}.A student wants to issue "1984" —check and print whether it is already issued.
issued={"Dune", "1984", "Emma"}
print("doees 1984 book issued? ",  "1984" in issued)
# Out:
# doees 1984 book issued?  True

# %%
#A quiz has participants from two rounds: round1 =["Alex", "Bella", "Chris", "Alex"]and round2 = ["Bella", "Dan", "Chris", "Eva"].Print the participants who took part in exactly one of the two rounds (not both).
round1 =set(["Alex", "Bella", "Chris", "Alex"])
round2 = set(["Bella", "Dan", "Chris", "Eva"])
print(round1)
print(round2)
round1^round2#took part in exactly one of the two rounds (not both).c:\Users\USER\Downloads\operators_in_python_practical.ipynb
# Out:
# {'Chris', 'Bella', 'Alex'}
# {'Dan', 'Chris', 'Bella', 'Eva'}
# {'Alex', 'Dan', 'Eva'}
