# %%
#Store your full name in a variable and print it in uppercase.
a="aysha nasni"
print(a.upper())
# Out:
# AYSHA NASNI

# %%
#A student's registered email is "student@gmail.com". Store it and print how many characters it contains
mail_id="student@gmail.com"
print("the no.of characters in the mail id is :", len(mail_id))
# Out:
# the no.of characters in the mail id is : 17

# %%
#A customer left this feedback: " Amazing product, highly recommend! ". Store it andprint it without the extra spaces at the start and end.
feedback="Amazing product, highly recommend!"
print(feedback.strip())
# Out:
# Amazing product, highly recommend!

# %%
#Ask the user to enter a book title in lowercase (for example, "the and print it the way it would appear on a book cover,  with each word capitalized.
book_title="Beauty and the beast"
print(book_title.title())
# Out:
# Beauty And The Beast

# %%
#A company slogan is stored as "We build apps for Java developers".Print the slogan after replacing "Java" with "Python".
slogan="We build apps for Java developers"
print(slogan.replace("Java","Python"))
# Out:
# We build apps for Python developers

# %%
#Ask the user to enter their full name and print just the first 4 letters as their username.
full_name=input("Enter the full name:" )
print(full_name[ :4])
# Out:
# SHAH

# %%
#A teacher stores the subjects she teaches as one line of text: "Maths,Science,English,History". Print each subject separately.

# %%
#Ask the user to enter a sentence and print the total number of words in it.
sentence=input("enter the sentence:")
print(len(sentence.split()))
# Out:
# 2

# %%
#Store the word "level". Print the word reversed, and also print whether the original word and the reversed word are exactly the same.
word="level"
reversed_word=word[ : :-1]
print(reversed_word)
print(word==reversed_word)
# Out:
# level
# True

# %%
#In the word "banana", print how many times the letter "a" appears.
word="banana"
print("number of times a appears is :", word.count("a"))
# Out:
# number of times a appears is : 3

# %%
#Ask the user to enter their username and print whether it starts with the text "admin".
username="administrator"
print(username.startswith("admin"))
# Out:
# True

# %%
#A user enters their date of birth as text in the format "17-09-2000". Print just the year part of it.
dob=input("enter the date of birth: ")
print(dob[6:])
# Out:
# 2000

# %%
#A user wants to save their top 3 favourite movies. Take all three as input from the user, one by one, store them in a list, and print the list.
movie_1=input("Enter your first favourite movie: ")
movie_2=input("Enter your second favourite movie: ")
movie_3=input("Enter your third favourite movie: ")
movies=[movie_1,movie_2,movie_3]
print(movies)
# Out:
# ['hjdh', 'fwr', 'wfw']

# %%
#A small shop's daily sales for a week are recorded as [1200, 1500, 900, 1700, 1100,2000, 1800]. Store this and print the sales of the highest and the lowest day.
sales=[1200, 1500, 900, 1700, 1100,2000, 1800]
print("Highest:", max(sales))
print("Lowest:" , min(sales))
# Out:
# Highest: 2000
# Lowest: 900

# %%
#A grocery list is ["Milk", "Bread", "Eggs"]. The customer forgot to add "Butter" — add it to the end of the list and print the updated list.
list=["Milk", "Bread", "Eggs"]
print(list)
list.append("Butter")
print(list)
# Out:
# ['Milk', 'Bread', 'Eggs']
# ['Milk', 'Bread', 'Eggs', 'Butter']

# %%
#A teacher recorded these marks: [56, 78, 45, 90, 67]. Print the total and the average mark.
marks=[56, 78, 45, 90, 67]
print("total mark is given as:" , sum(marks))
print("average mark is given as:" , sum(marks)/len(marks))
# Out:
# total mark is given as: 336
# average mark is given as: 67.2

# %%
#A playlist contains ["Song A", "Song B", "Song C", "Song D"]. The user wants "Song C" removed from it — update the list and print the result.
playlist=["Song A", "Song B", "Song C", "Song D"]
print(playlist)
playlist.remove("Song C")
print(playlist)
# Out:
# ['Song A', 'Song B', 'Song C', 'Song D']
# ['Song A', 'Song B', 'Song D']

# %%
#A list of ages is [15, 22, 34, 45, 19]. Print the ages arranged from smallest to largest.
ages=[15, 22, 34, 45, 19]
print(ages)
ages.sort()
print("arrangement from smallest to largest" , ages)
# Out:
# [15, 22, 34, 45, 19]
# arrangement from smallest to largest [15, 19, 22, 34, 45]

# %%
#A cricket team lineup is ["Rahul", "Aman", "Vikram", "Sunil", "Ravi"].The captain,"Vikram", got injured before the match,so he needs to be replaced with "Kiran" withoutchanging anyone else's position. Print the updated lineup.
lineup=["Rahul", "Aman", "Vikram", "Sunil", "Ravi"]
lineup[2]="Kiran"
print(lineup)
# Out:
# ['Rahul', 'Aman', 'Kiran', 'Sunil', 'Ravi']

# %%
#Two friends collected phone numbers separately:contacts1 = ["9998887771","9998887772"] and contacts2 = ["9998887773", "9998887774"]. Combine both into a single list and print it.
contacts_1= ["9998887771","9998887772"]
contacts_2=["9998887773", "9998887774"]
contacts=contacts_1+ contacts_2
print(contacts)
# Out:
# ['9998887771', '9998887772', '9998887773', '9998887774']

# %%
#A list of exam scores is [88, 45, 67, 45, 92, 45]. Print how many students scored exactly 45.
scores=[88, 45, 67, 45, 92, 45]
print("no.of times student scored 45: ",scores.count(45))
# Out:
# no.of times student scored 45:  3

# %%
#A delivery app stores restaurant ratings as [4.5, 3.8, 4.9, 4.1, 3.5].Print the highest rating among them
rating=[4.5, 3.8, 4.9, 4.1, 3.5]
print("Highest rating is:" , max(rating))
# Out:
# Highest rating is: 4.9

# %%
#A user enters 5 product prices one by one.Store them in a list and print the total bill amount.
Product1 = float(input("Enter first product price:"))
Product2 = float(input("Enter second product price:"))
Product3 = float(input("Enter third product price:"))
Product4 = float(input("Enter fourth product price:"))
Product5 = float(input("Enter fifth product price:"))
prices = [Product1,Product2,Product3,Product4,Product5]
print(prices)
print("total_bill_amount:",sum(prices))
# Out:
# [56.0, 54.0, 66.0, 44.0, 33.0]
# total_bill_amount: 253.0

# %%
#A list of usernames is ["admin", "guest123", "root", "test_user"].Print the position of "root" in the list.
list=["admin", "guest123", "root", "test_user"]
print("postion of rooot here:", list.index("root"))
# Out:
# postion of rooot here: 2
